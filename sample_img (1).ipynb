# %% [markdown]
# ![sample img.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# import cv2 as cv
# img = cv.imread("C:\Users\Nielit\Downloads")
#
# cv.imshow("display window", img)
# k = cv.waitkey(0)

# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread("/henry 3.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
